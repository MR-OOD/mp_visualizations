# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.colors import ListedColormap, to_rgba
from PIL import Image

def plot_mr_with_and_without_mask(
    mr_image_path,
    mask_image_path,
    alpha=0.4,
    figsize=(10, 5),
    mask_color="red"
):
    mr = np.array(Image.open(mr_image_path).convert("F"))  # grayscale float
    mask = np.array(Image.open(mask_image_path))

    if mask.ndim == 3:
        mask = np.array(Image.fromarray(mask).convert("L"))

    if mask.dtype.kind not in "iu":
        mask = (mask > 0).astype(np.uint8)

    if mask.shape != mr.shape:
        mask = np.array(Image.fromarray(mask).resize(mr.shape[::-1], Image.NEAREST))

    finite = np.isfinite(mr)
    vmin, vmax = np.percentile(mr[finite], [2, 98]) if finite.any() else (None, None)

    overlay_cmap = ListedColormap([to_rgba(mask_color)])

    fig, (ax1, ax2) = plt.subplots(1, 2, figsize=figsize)
    for ax in (ax1, ax2): ax.axis("off")

    ax1.imshow(mr, cmap="gray", vmin=vmin, vmax=vmax)
    ax1.set_title("Original MR")

    ax2.imshow(mr, cmap="gray", vmin=vmin, vmax=vmax)
    ax2.imshow(np.ma.masked_where(mask == 0, mask),
               cmap=overlay_cmap, alpha=alpha, interpolation="none")
    ax2.set_title("MR + Mask")

    plt.tight_layout()
    plt.show()
    return fig, (ax1, ax2)

# %%
mr_example_path = r'C:\Users\justi\Downloads\valid\Ungood\img\1PA151_48.png'
mask_example_path = r'C:\Users\justi\Downloads\valid\Ungood\label\1PA151_48.png'
plot_mr_with_and_without_mask(mr_example_path, mask_example_path)
# Out:
# (<Figure size 1000x500 with 2 Axes>,
#  (<Axes: title={'center': 'Original MR'}>,
#   <Axes: title={'center': 'MR + Mask'}>))

# %%
mr_example_path = r'C:\Users\justi\Downloads\valid_refined\Ungood\img\1PA151_51.png'
mask_example_path = r'C:\Users\justi\Downloads\valid_refined\Ungood\label\1PA151_51.png'
plot_mr_with_and_without_mask(mr_example_path, mask_example_path)
# Out:
# (<Figure size 1000x500 with 2 Axes>,
#  (<Axes: title={'center': 'Original MR'}>,
#   <Axes: title={'center': 'MR + Mask'}>))

# %%
mr_example_path = r'C:\Users\justi\OneDrive\Desktop\University\Master_Studium\MP\dataset\synth23_pelvis_v3\test\Ungood\img\1PA163_55.png'
mask_example_path = r'C:\Users\justi\OneDrive\Desktop\University\Master_Studium\MP\dataset\synth23_pelvis_v3\test\Ungood\label\1PA163_55.png'
plot_mr_with_and_without_mask(mr_example_path, mask_example_path)
# Out:
# (<Figure size 1000x500 with 2 Axes>,
#  (<Axes: title={'center': 'Original MR'}>,
#   <Axes: title={'center': 'MR + Mask'}>))

# %%
mr_example_path = r'C:\Users\justi\OneDrive\Desktop\University\Master_Studium\MP\dataset\synth23_metal_v2\test\Ungood\img\1PA163_55.png'
mask_example_path = r'C:\Users\justi\OneDrive\Desktop\University\Master_Studium\MP\dataset\synth23_metal_v2\test\Ungood\label\1PA163_55.png'
plot_mr_with_and_without_mask(mr_example_path, mask_example_path)
# Out:
# (<Figure size 1000x500 with 2 Axes>,
#  (<Axes: title={'center': 'Original MR'}>,
#   <Axes: title={'center': 'MR + Mask'}>))

# %%
mr_example_path = r'C:\Users\justi\OneDrive\Desktop\University\Master_Studium\MP\dataset\synth23_metal_v2\test\Ungood\img\1PA151_48.png'
mask_example_path = r'C:\Users\justi\OneDrive\Desktop\University\Master_Studium\MP\dataset\synth23_metal_v2\test\Ungood\label\1PA151_48.png'
plot_mr_with_and_without_mask(mr_example_path, mask_example_path)
# Out:
# (<Figure size 1000x500 with 2 Axes>,
#  (<Axes: title={'center': 'Original MR'}>,
#   <Axes: title={'center': 'MR + Mask'}>))

# %%
mr_example_path = r'C:\Users\justi\OneDrive\Desktop\University\Master_Studium\MP\dataset\synth23_metal_v2\test\Ungood\img\1PA152_62.png'
mask_example_path = r'C:\Users\justi\OneDrive\Desktop\University\Master_Studium\MP\dataset\synth23_metal_v2\test\Ungood\label\1PA152_62.png'
plot_mr_with_and_without_mask(mr_example_path, mask_example_path)
# Out:
# (<Figure size 1000x500 with 2 Axes>,
#  (<Axes: title={'center': 'Original MR'}>,
#   <Axes: title={'center': 'MR + Mask'}>))

# %%
mr_example_path = r'C:\Users\justi\OneDrive\Desktop\University\Master_Studium\MP\dataset\synth23_pelvis_v6_png\test\Ungood\img\1PA025_50.png'
mask_example_path = r'C:\Users\justi\OneDrive\Desktop\University\Master_Studium\MP\dataset\synth23_pelvis_v6_png\test\Ungood\label\1PA025_50.png'
plot_mr_with_and_without_mask(mr_example_path, mask_example_path)
# Out:
# (<Figure size 1000x500 with 2 Axes>,
#  (<Axes: title={'center': 'Original MR'}>,
#   <Axes: title={'center': 'MR + Mask'}>))

# %%
mr_example_path = r'C:\Users\justi\OneDrive\Desktop\University\Master_Studium\MP\dataset\synth23_pelvis_v6_png\test\Ungood\img\1PA118_75.png'
mask_example_path = r'C:\Users\justi\OneDrive\Desktop\University\Master_Studium\MP\dataset\synth23_pelvis_v6_png\test\Ungood\label\1PA118_75.png'
plot_mr_with_and_without_mask(mr_example_path, mask_example_path)
# Out:
# (<Figure size 1000x500 with 2 Axes>,
#  (<Axes: title={'center': 'Original MR'}>,
#   <Axes: title={'center': 'MR + Mask'}>))

# %%
mr_example_path = r'C:\Users\justi\OneDrive\Desktop\University\Master_Studium\MP\dataset\synth23_pelvis_v6_png\valid\Ungood\img\1PA151_52.png'
mask_example_path = r'C:\Users\justi\OneDrive\Desktop\University\Master_Studium\MP\dataset\synth23_pelvis_v6_png\valid\Ungood\label\1PA151_52.png'
plot_mr_with_and_without_mask(mr_example_path, mask_example_path)
# Out:
# (<Figure size 1000x500 with 2 Axes>,
#  (<Axes: title={'center': 'Original MR'}>,
#   <Axes: title={'center': 'MR + Mask'}>))
